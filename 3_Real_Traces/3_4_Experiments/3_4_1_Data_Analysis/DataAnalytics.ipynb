# %% [markdown]
# ## Trace-analytics

# %%
import pandas as pd

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# ### Dataset 1

# %%
df_data1 = pd.read_csv('../real_traces/SBOX_traces_fixed_2/traces/trace_sliced_4_12.csv',low_memory=False)

# %%
df_data1.describe()

# %%
df_data1.transpose()[0].plot()
df_data1.transpose()[1].plot()
df_data1.transpose()[2].plot()
df_data1.transpose()[3].plot()
df_data1.transpose()[4].plot()
df_data1.transpose()[5].plot()

# %%
sliced = df_data1.transpose()[850:2150].copy().reset_index(drop=True).transpose()

# %%
sliced.describe()
# Out:
#                0             1             2             3             4     \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     124.459300    116.520200    131.580900    124.518200    131.424200
# std       23.917942     24.736665     24.278707     24.381405     24.710846
# min       73.000000     70.000000     74.000000     76.000000     80.000000
# 25%      103.000000     95.000000    110.000000    102.000000    108.000000
# 50%      129.000000    112.000000    136.000000    121.000000    134.000000
# 75%      145.000000    139.000000    153.000000    147.000000    154.000000
# max      174.000000    174.000000    177.000000    179.000000    195.000000
#
#                5             6             7            8             9     \
# count  10000.000000  10000.000000  10000.000000  10000.00000  10000.000000
# mean     118.864000    113.715900    116.428800    113.47250    123.293000
# ...

# %%
sliced.transpose()[0].plot()
sliced.transpose()[1].plot()
sliced.transpose()[2].plot()
sliced.transpose()[3].plot()

# %% [markdown]
# ### Dataset 2

# %%
df_data2 = pd.read_csv('../real_traces/fixed_66_2500/fix66.csv')

# %%
df_data2.describe()
# Out:
#                   0            1             2             3            4  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.00000
# mean     115.303500    119.72570    127.337600    128.746200    119.18040
# std       23.865987     24.45168     24.705438     24.667802     23.85782
# min       67.000000     68.00000     73.000000     73.000000     71.00000
# 25%       93.000000     97.00000    104.000000    106.000000     97.00000
# 50%      115.000000    120.00000    128.000000    128.000000    119.00000
# 75%      137.000000    142.00000    150.000000    152.000000    141.00000
# max      171.000000    173.00000    178.000000    184.000000    174.00000
#
#                   5             6             7             8             9  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     108.986100    110.754400    117.941500    130.257500    141.428200
# ...

# %%
df_data2.transpose()[0].plot()
df_data2.transpose()[1].plot()
df_data2.transpose()[2].plot()
df_data2.transpose()[3].plot()
df_data2.transpose()[4].plot()
df_data2.transpose()[5].plot()

# %%
sliced2 = df_data2.transpose()[850:2150].copy().reset_index(drop=True).transpose()

# %%
sliced2.describe()
# Out:
#               0             1            2             3             4     \
# count  10000.00000  10000.000000  10000.00000  10000.000000  10000.000000
# mean     113.37010    120.195100    116.04050    124.384900    131.538300
# std       21.87445     23.466664     23.76759     24.152165     24.694876
# min       66.00000     66.000000     70.00000     72.000000     77.000000
# 25%       94.00000     98.000000     94.00000    102.000000    109.000000
# 50%      110.00000    123.000000    114.00000    125.000000    132.000000
# 75%      133.00000    141.000000    138.00000    147.000000    154.000000
# max      170.00000    173.000000    173.00000    179.000000    186.000000
#
#                5             6             7             8             9     \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     125.441200    123.203400    115.669400    121.377500    114.401600
# ...

# %%
sliced2.transpose()[0].plot()
sliced2.transpose()[1].plot()
sliced2.transpose()[2].plot()
sliced2.transpose()[3].plot()

# %%
meanTraces = sliced.mean() - sliced2.mean()

# %%
meanTraces[0:30]
# Out:
# 0    -0.3743
# 1     2.0286
# 2    -2.4774
# 3     2.3339
# 4    -2.6684
# 5     2.5008
# 6    -1.8572
# 7     1.6692
# 8    -0.6754
# 9     0.0950
# 10    0.1129
# 11   -1.7167
# 12    1.3674
# 13   -2.3061
# 14    2.7691
# 15   -1.9890
# 16    2.3849
# 17   -2.1964
# 18    1.0334
# 19   -0.3021
# 20    1.2026
# 21    1.5813
# 22   -1.2160
# 23    1.3846
# 24   -2.8792
# 25    1.7758
# 26   -2.4460
# 27    2.6277
# 28   -1.5182
# 29    1.6464
# dtype: float64

# %%
sliced['label'] = df_data1["label"]
sliced.to_csv("../real_traces/fixed_123_2500/sliced_123_1300.csv",index=False)

# %%
sliced2['label'] = df_data2["label"]
sliced2.to_csv("../real_traces/fixed_66_2500/sliced_66_1300.csv",index=False)

# %%
df_data3 = pd.read_csv('../real_traces/random_2500/random_2500.csv')

# %%
df_data3.describe()
# Out:
#                   0             1             2             3             4  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     115.158800    119.404000    127.330900    128.557400    119.283300
# std       23.850846     24.387929     24.328202     24.296801     23.752795
# min       65.000000     67.000000     74.000000     78.000000     72.000000
# 25%       92.000000     97.000000    105.000000    106.000000     97.000000
# 50%      115.000000    119.000000    128.000000    128.000000    119.000000
# 75%      137.000000    142.000000    150.000000    151.000000    141.000000
# max      173.000000    173.000000    178.000000    181.000000    175.000000
#
#                   5            6             7             8             9  \
# count  10000.000000  10000.00000  10000.000000  10000.000000  10000.000000
# mean     109.062500    110.64150    117.798400    129.798500    141.122700
# ...

# %%
df_data3.transpose()[0].plot()
df_data3.transpose()[1].plot()
df_data3.transpose()[2].plot()
df_data3.transpose()[3].plot()
df_data3.transpose()[4].plot()
df_data3.transpose()[5].plot()

# %%
sliced3 = df_data3.transpose()[850:2150].copy().reset_index(drop=True).transpose()

# %%
sliced3.describe()
# Out:
#                0             1             2             3             4     \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean     118.279000    119.555400    118.424400    128.896000    125.594700
# std       22.973575     23.604751     23.802902     24.757817     24.460484
# min       69.000000     67.000000     70.000000     75.000000     77.000000
# 25%       97.000000     97.000000     96.000000    106.000000    104.000000
# 50%      118.000000    120.000000    116.000000    132.000000    121.000000
# 75%      139.000000    142.000000    140.000000    152.000000    148.000000
# max      174.000000    170.000000    174.000000    179.000000    181.000000
#
#               5             6             7            8             9     \
# count  10000.00000  10000.000000  10000.000000  10000.00000  10000.000000
# mean     131.59360    113.066400    124.784000    112.07890    124.326000
# ...

# %%
sliced3.transpose()[0].plot()
sliced3.transpose()[1].plot()
sliced3.transpose()[2].plot()
sliced3.transpose()[3].plot()

# %%
sliced3['label'] = df_data3["label"]
sliced3.to_csv("../real_traces/random_2500/random_1300.csv",index=False)
